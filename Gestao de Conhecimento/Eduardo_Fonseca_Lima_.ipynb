# %% [markdown]
# # Semana 9

# %%
import pandas as pd

# %%
arquivo_csv="https://web.stanford.edu/class/cs102/datasets/CitiesExt.csv"

# %%
df_cidades = pd.read_csv(arquivo_csv)

# %%
df_cidades
# Out:
#             city         country  population  ... latitude longitude  temperature
# 0        Aalborg         Denmark        5.69  ...    57.03      9.92         7.52
# 1       Aberdeen  United Kingdom       65.11  ...    57.17     -2.08         8.10
# 2         Abisko          Sweden        9.85  ...    63.35     18.83         0.20
# 3          Adana          Turkey       79.62  ...    36.99     35.32        18.67
# 4       Albacete           Spain       46.06  ...    39.00     -1.87        12.62
# ..           ...             ...         ...  ...      ...       ...          ...
# 208  Yevpatoriya         Ukraine       44.62  ...    45.20     33.36        10.02
# 209     Zaragoza           Spain       46.06  ...    41.65     -0.89        14.17
# 210     Zhytomyr         Ukraine       44.62  ...    50.25     28.66         6.67
# 211    Zonguldak          Turkey       79.62  ...    41.43     31.78        10.64
# ...

# %%
df_cidades.describe()
# Out:
#        population    latitude   longitude  temperature
# count  213.000000  213.000000  213.000000   213.000000
# mean    40.090845   47.499906   15.374319     9.497840
# std     28.727819    6.730961   13.068014     3.561231
# min      0.070000   36.130000   -9.140000    -2.200000
# 25%      9.480000   42.220000    5.380000     7.190000
# 50%     44.620000   47.580000   16.180000     8.880000
# 75%     64.670000   52.050000   25.620000    11.190000
# max     80.680000   67.850000   41.930000    18.670000

# %%
df_cidades['temperature']
# Out:
# 0       7.52
# 1       8.10
# 2       0.20
# 3      18.67
# 4      12.62
#        ...
# 208    10.02
# 209    14.17
# 210     6.67
# 211    10.64
# 212     6.68
# Name: temperature, Length: 213, dtype: float64

# %%
df_cidades.head(10)
# Out:
#         city         country  population  ... latitude longitude  temperature
# 0    Aalborg         Denmark        5.69  ...    57.03      9.92         7.52
# 1   Aberdeen  United Kingdom       65.11  ...    57.17     -2.08         8.10
# 2     Abisko          Sweden        9.85  ...    63.35     18.83         0.20
# 3      Adana          Turkey       79.62  ...    36.99     35.32        18.67
# 4   Albacete           Spain       46.06  ...    39.00     -1.87        12.62
# 5  Algeciras           Spain       46.06  ...    36.13     -5.47        17.38
# 6     Amiens          France       64.67  ...    49.90      2.30        10.17
# 7  Amsterdam     Netherlands       16.98  ...    52.35      4.92         8.93
# 8     Ancona           Italy       59.80  ...    43.60     13.50        13.52
# 9    Andorra         Andorra        0.07  ...    42.50      1.52         9.60
#
# [10 rows x 8 columns]

# %%
df_cidades.tail()
# Out:
#             city      country  population  ... latitude longitude  temperature
# 208  Yevpatoriya      Ukraine       44.62  ...    45.20     33.36        10.02
# 209     Zaragoza        Spain       46.06  ...    41.65     -0.89        14.17
# 210     Zhytomyr      Ukraine       44.62  ...    50.25     28.66         6.67
# 211    Zonguldak       Turkey       79.62  ...    41.43     31.78        10.64
# 212       Zurich  Switzerland        8.38  ...    47.38      8.56         6.68
#
# [5 rows x 8 columns]

# %%
df_cidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         213 non-null    object
#  1   country      213 non-null    object
#  2   population   213 non-null    float64
#  3   EU           213 non-null    object
#  4   coastline    213 non-null    object
#  5   latitude     213 non-null    float64
#  6   longitude    213 non-null    float64
#  7   temperature  213 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 13.4+ KB

# %%
df_cidades[ df_cidades['temperature'] < 5]
# Out:
#           city  country  population  ... latitude longitude  temperature
# 2       Abisko   Sweden        9.85  ...    63.35     18.83         0.20
# 15    Augsburg  Germany       80.68  ...    48.35     10.90         4.54
# 27      Bergen   Norway        5.27  ...    60.39      5.32         1.75
# 35        Bodo   Norway        5.27  ...    67.25     14.40         4.50
# 100   Helsinki  Finland        5.52  ...    60.18     24.93         4.19
# 105  Innsbruck  Austria        8.57  ...    47.28     11.41         4.54
# 116     Kiruna   Sweden        9.85  ...    67.85     20.22        -2.20
# 151      Orsha  Belarus        9.48  ...    54.52     30.42         4.93
# 152       Oslo   Norway        5.27  ...    59.92     10.75         2.32
# 154       Oulu  Finland        5.52  ...    65.00     25.47         1.45
# 175   Salzburg  Austria        8.57  ...    47.81     13.04         4.62
# 190    Tallinn  Estonia        1.31  ...    59.43     24.73         4.82
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
plt.figure(figsize =(15,5))

# %%
plt.plot(df_cidades['city'], df_cidades['temperature'])

# %% [markdown]
# Aluno: Eduardo Fonseca Lima
#
# Matrícula: 0050014914
